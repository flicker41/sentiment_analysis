# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
from sklearn.feature_extraction.text import TfidfVectorizer as tfv
from sklearn.linear_model import LogisticRegression
import joblib
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("sentimentData.csv")
df.head()
# Out:
#                            text sentiment
# 0           I love this product  Positive
# 1               This is amazing  Positive
# 2             Excellent service  Positive
# 3  Very happy with the purchase  Positive
# 4             Fantastic quality  Positive

# %%
X=df['text']
y=df['sentiment']

# %%
vect=tfv()
X_vector=vect.fit_transform(X)

# %%
X_train,x_test,y_train,y_test=train_test_split(X_vector,y,test_size=0.2,random_state=45)
model=LogisticRegression()
model.fit(X_train,y_train)
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.3333333333333333

# %%
joblib.dump(model,"model.pkl")
joblib.dump(model,"vect.pkl")
# Out:
# ['vect.pkl']
